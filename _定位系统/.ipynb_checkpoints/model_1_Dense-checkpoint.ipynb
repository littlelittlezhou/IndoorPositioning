# %%
import numpy as np
import pandas as pd
import keras
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation,Dropout,Conv2D,MaxPooling2D, Flatten
from keras import optimizers
from keras import regularizers
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from keras import models
from keras import layers
import random
import csv
from sklearn.model_selection import KFold

# %%
class LossHistory(keras.callbacks.Callback): # 回调函数, 用于查看训练模型的内在状态和统计
    #  在训练时， 相应的回调函数的方法会被在各自的阶段被调用
    def on_train_begin(self, logs={}): # 在模型开始训练时被调用
        self.losses = {'batch':[], 'epoch':[]}              #创建每批结束和每轮结束的记录数组
        self.accuracy = {'batch':[], 'epoch':[]}           
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_accuracy = {'batch':[], 'epoch':[]} 
        
    def on_batch_end(self, batch, logs={}): # 在每批结束时被调用

        self.losses['batch'].append(logs.get('loss'))       #记录每批结束的训练损失
        self.accuracy['batch'].append(logs.get('accuracy')) #记录每批结束的训练精确度
        self.val_loss['batch'].append(logs.get('val_loss')) #记录每批结束的验证损失
        self.val_accuracy['batch'].append(logs.get('val_accuracy'))   #记录每批结束的验证精确度 
        
    def on_epoch_end(self, batch, logs={}): # 在每轮结束时被调用
        self.losses['epoch'].append(logs.get('loss'))       #记录每轮结束的训练损失
        self.accuracy['epoch'].append(logs.get('accuracy')) #记录每轮结束的训练精确度
        self.val_loss['epoch'].append(logs.get('val_loss')) #记录每轮结束的验证损失
        self.val_accuracy['epoch'].append(logs.get('val_accuracy'))   #记录每轮结束的验证精确度

    def loss_plot(self, loss_type,modelname):
        iters = range(len(self.losses[loss_type]))
    
        # acc loss
        plt.figure()
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train accuracy')
        
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        plt.plot(iters, self.val_accuracy[loss_type],'yo',label='Validation accuracy')
        plt.plot(iters, self.val_loss[loss_type],'bo',label='Validation loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('acc-loss')
        plt.legend(loc="upper right")
        plt.savefig(modelname+"_acc_{}.png".format(k)) #保存为图片

# %%
# 导入数据
#该方法用于引入数据集，数据集要求为已经向量化的数据
#输入为文件名，默认在/Data文件夹中，数据形式为【区域，x，y，样本】
#返回为labels，samples，同索引的对应
def Dataset(Filename):
    datas = pd.read_csv("./Data/"+Filename,header=None)
    datas = np.array(datas)
    labels = datas[:,:3]    # csv数据中，前三列为label：区域，x，y
    samples = datas[:,3:]   # 之后的为样本
    return labels,samples

# %%
# 定义model_1

def model_1():
    model = models.Sequential()
    model.add(layers.Dense(300,activation='relu',input_dim=469))
#     model.add(layers.Dropout(0.5))
    model.add(layers.Dense(200,kernel_regularizer=keras.regularizers.l2(0.01),activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(64,activation='relu'))
    model.add(layers.Dense(32,activation='softmax'))
    
#     rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(loss='categorical_crossentropy', optimizer=adam,metrics=['accuracy'])
#     model.compile(optimizer=rmsprop,
#                   loss='categorical_crossentropy',
#                   metrics=['accuracy'])
    return model

# %%
# K折验证数据划分

all_histories = [] # 存储所有的history
model_1 = model_1() # 构建模型
model_1.summary() #总结模型


# test_y,test_x = Dataset("Test_0.csv")
# train_y,train_x = Dataset("Train_0.csv")

test_y,test_x = Dataset("Test_1.csv")
train_y,train_x = Dataset("Train_1.csv")
# 对标签进行处理
test_y = test_y[:,0] # 区域号位于第0列，所以取出区域号
test_y -= 1 # 将原本区域号是1~32，对应到0~31
y_test = to_categorical(test_y,32) # one-hot编码
# 对标签进行处理
train_y = train_y[:,0] # 区域号位于第0列，所以取出区域号
train_y -= 1 # 将原本区域号是1~32，对应到0~31
y_train = to_categorical(train_y,32) # one-hot编码

# 对样本数据进行处理
test_x[test_x == 0] = -120 # 将信号强度为0的数据，设置为-120 表示Rssi最弱
normalize = MinMaxScaler() # 引入归一化方法，即 按axis=0，（当前值-最小值）/（最大值-最小值）
X_test = normalize.fit_transform(test_x) # fit_transform 会先拟合部分数据，找到normalize中所要用到的特征值
# 对样本数据进行处理
train_x[train_x == 0] = -120 # 将信号强度为0的数据，设置为-120 表示Rssi最弱
normalize = MinMaxScaler() # 引入归一化方法，即 按axis=0，（当前值-最小值）/（最大值-最小值）
X_train = normalize.fit_transform(train_x) # fit_transform 会先拟合部分数据，找到normalize中所要用到的特征值


# 划分测试集
# X_train,X_test,y_train,y_test = train_test_split(samples_normalized,labels,test_size=0.2) #划分20%的数据作为测试数据
#  K折交叉验证
kf = KFold(n_splits=5, shuffle=True) # 5折交叉验证
k = 0 # 用于记录验证次数,初始化为0
for tra_index, val_index in kf.split(X_train,y_train):
#     print(" Train Index:\n", tra_index)
    X_train_tra = X_train[tra_index]
    print(X_train_tra.shape)
    X_train_val = X_train[val_index]
    print(X_train_val.shape)
#     print(" Val Index:\n", val_index)
    y_train_tra = y_train[tra_index]
    y_train_val = y_train[val_index]
    print(y_train_tra.shape)
    print(y_train_val.shape)
    k += 1 # 验证次数+1
    history = LossHistory()
    print('Training 第{}次 ------------'.format(k))
    model_1.fit(X_train_tra, y_train_tra, batch_size=32,epochs=50,  callbacks=[history], validation_data=(X_train_val,y_train_val))
    print('\nTesting 第{}次 ------------'.format(k))
    # 评价训练出的网络
    loss, accuracy = model_1.evaluate(X_test, y_test)
    print('test loss: ', loss)
    print('test accuracy: ', accuracy)
    history.loss_plot('epoch',"./Phase_1/model_1")
    all_histories.append(history) #加入每次的记录
    
model_1.save("./Phase_1/model_1.h5")
# model_1.save("./Phase_1/model_0.h5")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 300)               141000
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               60200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                12864
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                2080
# =================================================================
# Total params: 216,144
# Trainable params: 216,144
# Non-trainable params: 0
# _________________________________________________________________
# (1124, 469)
# (281, 469)
# (1124, 32)
# (281, 32)
# Training 第1次 ------------
# Epoch 1/50
# 36/36 [==============================] - 2s 19ms/step - loss: 5.2847 - accuracy: 0.1326 - val_loss: 3.4383 - val_accuracy: 0.2883
# Epoch 2/50
# 36/36 [==============================] - 0s 9ms/step - loss: 3.1401 - accuracy: 0.3874 - val_loss: 2.1373 - val_accuracy: 0.6370
# Epoch 3/50
# 36/36 [==============================] - 0s 8ms/step - loss: 2.0994 - accuracy: 0.5717 - val_loss: 1.4430 - val_accuracy: 0.7936
# Epoch 4/50
# 36/36 [==============================] - 0s 9ms/step - loss: 1.5134 - accuracy: 0.7134 - val_loss: 1.1136 - val_accuracy: 0.8577
# Epoch 5/50
# 36/36 [==============================] - 0s 9ms/step - loss: 1.2258 - accuracy: 0.7667 - val_loss: 0.9429 - val_accuracy: 0.8932
# Epoch 6/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0
50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0918 - accuracy: 0.9911 - val_loss: 0.1189 - val_accuracy: 0.9751
# Epoch 47/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1046 - accuracy: 0.9858 - val_loss: 0.1482 - val_accuracy: 0.9715
# Epoch 48/50
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0971 - accuracy: 0.9875 - val_loss: 0.1161 - val_accuracy: 0.9822
# Epoch 49/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1179 - accuracy: 0.9813 - val_loss: 0.1390 - val_accuracy: 0.9751
# Epoch 50/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1157 - accuracy: 0.9867 - val_loss: 0.1222 - val_accuracy: 0.9786
#
# Testing 第2次 ------------
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2264 - accuracy: 0.9574
# test loss:  0.22642828524112701
# test accuracy:  0.9573863744735718
# (1124, 469)
# (281, 469)
# (1124, 32)
# (281, 32)
# Training 第3次 ------------
# Epoch 1/50
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1253 - accuracy: 0.9813 - val_loss: 0.0900 - val_accuracy: 0.9929
# Epoch 2/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1308 - accuracy: 0.9813 - val_loss: 0.0892 - val_accuracy: 0.9929
# Epoch 3/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1249 - accuracy: 0.9849 - val_loss: 0.0946 - val_accuracy: 0.9929
# Epoch 4/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.1060 - accuracy: 0.9893 - val_loss: 0.0787 - val_accuracy: 0.9929
# Epoch 5/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0998 - accuracy: 0.9858 - val_loss: 0.0811 - val_accuracy: 0.9893
# Epoch 6/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0936 - accuracy: 0.9902 - val_loss: 0.0694 - val_accuracy: 0.9893
# Epoch 7/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0883 - accuracy: 0.9840 - val_loss: 0.0859 - val_accuracy: 0.9858
# Epoch 8/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0969 - accuracy: 0.9840 - val_loss: 0.0823 - val_accuracy: 0.9858
# Epoch 9/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0995 - accuracy: 0.9884 - val_loss: 0.0858 - val_accuracy: 0.9893
# Epoch 10/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0999 - accuracy: 0.9858 - val_loss: 0.0877 - val_accuracy: 0.9893
# Epoch 11/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0974 - accuracy: 0.9884 - val_loss: 0.0817 - val_accuracy: 0.9893
# Epoch 12/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0938 - accuracy: 0.9902 - val_loss: 0.0968 - val_accuracy: 0.9786
# Epoch 13/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1093 - accuracy: 0.9840 - val_loss: 0.0863 - val_accuracy: 0.9858
# Epoch 14/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0971 - accuracy: 0.9902 - val_loss: 0.1082 - val_accuracy: 0.9893
# Epoch 15/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1658 - accuracy: 0.9751 - val_loss: 0.1296 - val_accuracy: 0.9822
# Epoch 16/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1257 - accuracy: 0.9893 - val_loss: 0.1140 - val_accuracy: 0.9929
# Epoch 17/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.1180 - accuracy: 0.9884 - val_loss: 0.1150 - val_accuracy: 0.9858
# Epoch 18/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1060 - accuracy: 0.9884 - val_loss: 0.0892 - val_accuracy: 0.9893
# Epoch 19/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.1166 - accuracy: 0.9858 - val_loss: 0.0740 - val_accuracy: 0.9893
# Epoch 20/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0817 - accuracy: 0.9938 - val_loss: 0.0851 - val_accuracy: 0.9893
# Epoch 21/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0821 - accuracy: 0.9884 - val_loss: 0.0761 - val_accuracy: 0.9858
# Epoch 22/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0800 - accuracy: 0.9893 - val_loss: 0.0933 - val_accuracy: 0.9858
# Epoch 23/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0816 - accuracy: 0.9884 - val_loss: 0.0958 - val_accuracy: 0.9822
# Epoch 24/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1162 - accuracy: 0.9840 - val_loss: 0.1416 - val_accuracy: 0.9822
# Epoch 25/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1088 - accuracy: 0.9893 - val_loss: 0.1087 - val_accuracy: 0.9858
# Epoch 26/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.
50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1953 - accuracy: 0.9786 - val_loss: 0.1503 - val_accuracy: 0.9822
# Epoch 41/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1446 - accuracy: 0.9822 - val_loss: 0.1617 - val_accuracy: 0.9715
# Epoch 42/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1241 - accuracy: 0.9902 - val_loss: 0.1045 - val_accuracy: 0.9964
# Epoch 43/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1283 - accuracy: 0.9858 - val_loss: 0.1179 - val_accuracy: 0.9893
# Epoch 44/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0977 - accuracy: 0.9938 - val_loss: 0.1053 - val_accuracy: 0.9893
# Epoch 45/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0798 - accuracy: 0.9956 - val_loss: 0.0779 - val_accuracy: 0.9929
# Epoch 46/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0707 - accuracy: 0.9929 - val_loss: 0.0680 - val_accuracy: 0.9893
# Epoch 47/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0610 - accuracy: 0.9947 - val_loss: 0.0723 - val_accuracy: 0.9858
# Epoch 48/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0570 - accuracy: 0.9947 - val_loss: 0.0511 - val_accuracy: 0.9929
# Epoch 49/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0582 - accuracy: 0.9929 - val_loss: 0.0665 - val_accuracy: 0.9893
# Epoch 50/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0498 - accuracy: 0.9947 - val_loss: 0.0606 - val_accuracy: 0.9929
#
# Testing 第4次 ------------
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1860 - accuracy: 0.9545
# test loss:  0.18602505326271057
# test accuracy:  0.9545454382896423
# (1124, 469)
# (281, 469)
# (1124, 32)
# (281, 32)
# Training 第5次 ------------
# Epoch 1/50
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0706 - accuracy: 0.9884 - val_loss: 0.0630 - val_accuracy: 0.9929
# Epoch 2/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0862 - accuracy: 0.9893 - val_loss: 0.0755 - val_accuracy: 0.9929
# Epoch 3/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0820 - accuracy: 0.9929 - val_loss: 0.0907 - val_accuracy: 0.9893
# Epoch 4/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0916 - accuracy: 0.9884 - val_loss: 0.0963 - val_accuracy: 0.9858
# Epoch 5/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1452 - accuracy: 0.9858 - val_loss: 0.1092 - val_accuracy: 0.9822
# Epoch 6/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1048 - accuracy: 0.9902 - val_loss: 0.1157 - val_accuracy: 0.9858
# Epoch 7/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1013 - accuracy: 0.9875 - val_loss: 0.1132 - val_accuracy: 0.9858
# Epoch 8/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0835 - accuracy: 0.9956 - val_loss: 0.0878 - val_accuracy: 0.9893
# Epoch 9/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0791 - accuracy: 0.9929 - val_loss: 0.0922 - val_accuracy: 0.9858
# Epoch 10/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0717 - accuracy: 0.9920 - val_loss: 0.0836 - val_accuracy: 0.9858
# Epoch 11/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0731 - accuracy: 0.9902 - val_loss: 0.0749 - val_accuracy: 0.9822
# Epoch 12/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0934 - accuracy: 0.9893 - val_loss: 0.1213 - val_accuracy: 0.9786
# Epoch 13/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0822 - accuracy: 0.9902 - val_loss: 0.0913 - val_accuracy: 0.9822
# Epoch 14/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0702 - accuracy: 0.9938 - val_loss: 0.0857 - val_accuracy: 0.9786
# Epoch 15/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0859 - accuracy: 0.9893 - val_loss: 0.0957 - val_accuracy: 0.9858
# Epoch 16/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0811 - accuracy: 0.9929 - val_loss: 0.1011 - val_accuracy: 0.9858
# Epoch 17/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0832 - accuracy: 0.9938 - val_loss: 0.0985 - val_accuracy: 0.9822
# Epoch 18/50
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0776 - accuracy: 0.9956 - val_loss: 0.1056 - val_accuracy: 0.9858
# Epoch 19/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0789 - accuracy: 0.9920 - val_loss: 0.0768 - val_accuracy: 0.9893
# Epoch 20/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0802 - accuracy: 0.9920 - val_loss: 0.1015 - val_accuracy: 0.9822
# Epoch 21/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0726 - accuracy: 0.9929 - val_loss: 0.0969 - val_accuracy: 0.9858
# Epoch 22/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0648 - accuracy: 0.9964 - val_loss: 0.0663 - val_accuracy: 0.9893
# Epoch 23/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0541 - accuracy: 0.9973 - val_loss: 0.0727 - val_accuracy: 0.9858
# Epoch 24/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0618 - accuracy: 0.9929 - val_loss: 0.0884 - val_accuracy: 0.9822
# Epoch 25/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0509 - accuracy: 0.9947 - val_loss: 0.0891 - val_accuracy: 0.9822
# Epoch 26/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0463 - accuracy: 0.9964 - val_loss: 0.0830 - val_accuracy: 0.9822
# Epoch 27/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0377 - accuracy: 0.9982 - val_loss: 0.0745 - val_accuracy: 0.9858
# Epoch 28/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0391 - accuracy: 0.9973 - val_loss: 0.0732 - val_accuracy: 0.9858
# Epoch 29/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0377 - accuracy: 0.9982 - val_loss: 0.0747 - val_accuracy: 0.9786
# Epoch 30/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0531 - accuracy: 0.9938 - val_loss: 0.0919 - val_accuracy: 0.9822
# Epoch 31/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0551 - accuracy: 0.9920 - val_loss: 0.1010 - val_accuracy: 0.9822
# Epoch 32/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0603 - accuracy: 0.9902 - val_loss: 0.0923 - val_accuracy: 0.9786
# Epoch 33/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0577 - accuracy: 0.9964 - val_loss: 0.1007 - val_accuracy: 0.9786
# Epoch 34/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0837 - accuracy: 0.9911 - val_loss: 0.1326 - val_accuracy: 0.9822
# Epoch 35/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1588 - accuracy: 0.9813 - val_loss: 0.1657 - val_accuracy: 0.9858
# Epoch 36/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1512 - accuracy: 0.9947 - val_loss: 0.2006 - val_accuracy: 0.9822
# Epoch 37/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1469 - accuracy: 0.9884 - val_loss: 0.1805 - val_accuracy: 0.9822
# Epoch 38/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1226 - accuracy: 0.9920 - val_loss: 0.1693 - val_accuracy: 0.9822
# Epoch 39/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1029 - accuracy: 0.9938 - val_loss: 0.1226 - val_accuracy: 0.9858
# Epoch 40/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1022 - accuracy: 0.9902 - val_loss: 0.1193 - val_accuracy: 0.9858
# Epoch 41/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0801 - accuracy: 0.9929 - val_loss: 0.1045 - val_accuracy: 0.9858
# Epoch 42/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0719 - accuracy: 0.9938 - val_loss: 0.1091 - val_accuracy: 0.9786
# Epoch 43/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0571 - accuracy: 0.9973 - val_loss: 0.1004 - val_accuracy: 0.9786
# Epoch 44/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0640 - accuracy: 0.9929 - val_loss: 0.1071 - val_accuracy: 0.9786
# Epoch 45/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0548 - accuracy: 0.9964 - val_loss: 0.0770 - val_accuracy: 0.9858
# Epoch 46/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0483 - accuracy: 0.9956 - val_loss: 0.0874 - val_accuracy: 0.9786
# Epoch 47/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0515 - accuracy: 0.9938 - val_loss: 0.0895 - val_accuracy: 0.9858
# Epoch 48/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0458 - accuracy: 0.9956 - val_loss: 0.0706 - val_accuracy: 0.9858
# Epoch 49/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0442 - accuracy: 0.9938 - val_loss: 0.0594 - val_accuracy: 0.9858
# Epoch 50/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0399 - accuracy: 0.9964 - val_loss: 0.0855 - val_accuracy: 0.9858
#
# Testing 第5次 ------------
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2080 - accuracy: 0.9545
# test loss:  0.20800217986106873
# test accuracy:  0.9545454382896423
