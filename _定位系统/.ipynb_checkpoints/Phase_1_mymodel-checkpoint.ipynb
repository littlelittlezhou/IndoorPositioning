# %%
import IPYNB_IMPORTER
import Phase2
from DivisionForP2 import Dataset
import numpy as np
import keras
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation,Dropout,Conv2D,MaxPooling2D, Flatten
from keras.optimizers import RMSprop,Nadam,Adam
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import random
from keras.utils.vis_utils import plot_model

# %%
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]} 
        
    def on_batch_end(self, batch, logs={}):

        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('accuracy'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_accuracy'))
        
    def on_epoch_end(self, batch, logs={}):
        
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('accuracy'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_accuracy'))

    def loss_plot(self, loss_type,modelname):
        iters = range(len(self.losses[loss_type]))
    
        # acc
        plt.figure()
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train acc')
        if loss_type == 'epoch':
            # val_acc
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val acc')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('acc')
        plt.legend(loc="upper right")
        plt.savefig(modelname+"_acc.png")
        plt.show()

        # loss
        plt.figure()
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('loss')
        plt.legend(loc="upper right")
        plt.savefig(modelname+"_los.png")
        plt.show()

# %%
# 样本数据处理
# 输入：训练集样本数据或者测试集样本数据
# 输出：匹配CNN模型的输入数据
def X_data_processing(X):
    X[X==0] = -120
    normalize = MinMaxScaler()
    normalize.fit(X)
    X = normalize.transform(X)
    zero_test = np.zeros((len(X),15),dtype=float) #生成15个全零，用于扩充训练数据（469-》484=22*22）
    X_process = np.concatenate((X,zero_test),axis=1)    # 延长每个向量到22*22
    X_process = X_process.reshape(len(X_process),22,22)
    X_process = np.expand_dims(X_process,axis=3)
    return X_process

# %%
# 区域号数据处理
# 输入：区域号
# 输出：one-hot编码之后的区域号
def area_data_processing(area):
    area = area -1
    area = to_categorical(area,32) 
    return area

# %%
# 尝试写一个用于数据增强的数据生成器，这个生成器将放在fit_generator里面使用，直接生成增强数据
## 它应该接收原本用于训练的数据集作为输入
# X：原始样本，样本数不定，样本长度为469.未经过预处理。
# y：原始标签，样本数随X，长度为3，（区域，x，y），仅使用区域，需进一步处理和提取。
## 它应该输出一个用于训练的元组（gen_x,gen_y）
######gen_y :按照训练集生成的虚拟样本的标签，要根据该标签生成样本，它应该是经过预处理之后的标签，而不是长度为3的原始样子。
# gen_y的生成法：等概率地随机抽取区域。
# gen_y的预处理法：区域标记序号自然数将转化为长度为32的one-hot向量。
######gen_x：按照训练集生成的虚拟样本，它们应该依据样本特性随机产生，产生后需要经过预处理，以便直接投入模型训练。
# gen_x的生成法：首先确定该次随机样本的区域，根据区域特点确定每个AP的随机规则*，依次随机AP的读数。
# gen_x的预处理法：对0读数赋予-120的rssi值，再进行最大最小标准化。
#####################
# *随机规则：1.认为每个区域具有相同的属性。
#            2.该AP在该区域是否在实际数据集中取到过值？
#                Y: 计算取到值和未取到（0）之间的比例，从而计算未取到值（0）的概率p，进入下一行；
#                   该AP的随机读数将有p的概率为0。若随机结果为“是0”，退出，结果为0；若随机结果是“不为0”，进入下一行；
#                   计算该AP历史实际读数的最大值max、最小值min，该AP的随机读数r将在区间[min,max]随机产生，进入下一行；
#                   添加随机波动，r = r ± 5，退出。
#                N: 为0，退出。

def datagen(X,y,normalizer,batch_size=32): #X是训练数据集，y是训练标签集
    # 第一步：计算各个区域的每AP的属性。
    # 属性：为0的概率p。
    #       取值历史最小值min。
    #       取值历史最大值max。
    x_div_by_area,y_div_by_area = Phase2.DivByArea(X,y)#按区域进行划分
    attr = {}
    for area,samples in x_div_by_area.items():          #对于每一个区域
        total = len(samples)    # 该区域样本总个数
        zero = sum(samples == 0)  # 该区域每一列0的个数
        ratio = zero/total       # 该区域样本每个ap取0的可能性
        min_ = np.amin(samples,axis=0)   # 该区域可以取到的最小值
        samples[samples==0] = -120
        max_ = np.amax(samples,axis=0)   # 该区域可以取到的最大值
        # 已计算出 ratio min_ max_
        attr[area] = (ratio,min_,max_)
    while True:  
        vXs = [] #随机变换之后的样本集
        vys = [] #随机变换之后的标签集   
        for i in range(batch_size):
            area = random.randint(1,32)     # 每一次随机选择样本所处区域
            vX = []                # 预设一个虚拟X
            #取出需要的区域参数
            ratio = attr[area][0] #为0的概率
            min_ = attr[area][1]  #最小的可能取值
            max_ = attr[area][2] #最大的可能取值
            for apnum in range(len(X[0])):
                if random.random() < ratio[apnum]: #随机结果的概率小于该列取零的概率，即随机结果认为该AP取值应该为0 
                    ##random.random() 返回随机生成的一个在[0,1]范围的实数
                    vX.append(0)
                else:         # 随机结果认为该ap取值不应为0
                    temp = random.randint(min_[apnum],max_[apnum])#就在该列取值的最大值和最小值之间随机生成一个数
                    error = random.randint(-5,5) #随机产生一个（-5，5）之间的误差
                    temp = temp+error #随机结果认为该AP应该的取值
                    vX.append(temp)
            vXs.append(vX)
            vys.append(area)
            
        ###################### 下面是预处理流程
        vXs = np.array(vXs)   # 转为numpy数组
        vys = np.array(vys) 
        vXs_exp = X_data_processing(vXs)#处理vXs数据
        vys = area_data_processing(vys)
        yield (vXs_exp,vys)

# %%
y_test,X_test = Dataset("Test_1.csv")
y_train,X_train = Dataset("Train_1.csv")
normalize = MinMaxScaler()
X_test_exp = X_data_processing(X_test)#处理样本数据
area_test = y_test[:,0]
area_test = area_data_processing(area_test)
area_true = np.argmax(area_test,axis=1)+1

# %%
mymodel = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(22,22,1)),
    MaxPooling2D(pool_size=(2, 2)), #最大池化层
    Conv2D(32,(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),  
    Dense(64,activation='relu'),
    Dropout(0.5),
    Dense(32),
    Activation('softmax'),
])

# 定义优化器
rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
mymodel.compile(optimizer=rmsprop,
              loss='categorical_crossentropy',
              metrics=['accuracy']) # metrics赋值为'accuracy'，会在训练过程中输出正确率

history = LossHistory()

# %%
mymodel.summary()
plot_model(mymodel,to_file=".\Picture\model_2.png",show_shapes=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 20, 20, 32)        320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 32)          9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# =================================================================
# Total params: 44,480
# Trainable params: 44,480
# Non-trainable params: 0
# _________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
print('Training ------------')
mymodel.fit_generator(datagen(X_train,y_train,normalize), steps_per_epoch = 100, epochs = 100, validation_data=(X_test_exp,area_test), callbacks=[history])
print('\nTesting ------------')
# 评价训练出的网络
loss, accuracy = mymodel.evaluate(X_test_exp, area_test)

print('test loss: ', loss)
print('test accuracy: ', accuracy)
history.loss_plot('epoch',"./Phase_1/model_2")

mymodel.save("./Phase_1/model_2.h5")
# Out:
# Training ------------
# D:\Download\packet\work\_Aconda\_install\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 100/100 [==============================] - 5s 36ms/step - loss: 3.2685 - accuracy: 0.1054 - val_loss: 2.2139 - val_accuracy: 0.4460
# Epoch 2/100
# 100/100 [==============================] - 3s 32ms/step - loss: 2.0396 - accuracy: 0.3569 - val_loss: 1.1574 - val_accuracy: 0.7443
# Epoch 3/100
# 100/100 [==============================] - 3s 32ms/step - loss: 1.3172 - accuracy: 0.5533 - val_loss: 0.7053 - val_accuracy: 0.8040
# Epoch 4/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.9644 - accuracy: 0.6444 - val_loss: 0.5178 - val_accuracy: 0.8636
# Epoch 5/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.7427 - accuracy: 0.7284 - val_loss: 0.4049 - val_accuracy: 0.8835
# Epoch 6/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5840 - accuracy: 0.7901 - val_loss: 0.3799 - val_accuracy: 0.8636
# Epoch 7/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.5099 - accuracy: 0.8134 - val_loss: 0.3451 - val_accuracy: 0.8693
# Epoch 8/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4119 - accuracy: 0.8532 - val_loss: 0.3174 - val_accuracy: 0.8864
# Epoch 9/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3997 - accuracy: 0.8551 - val_loss: 0.3550 - val_accuracy: 0.8750
# Epoch 10/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3599 - accuracy: 0.8692 - val_loss: 0.3124 - val_accuracy: 0.8977
# Epoch 11/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3257 - accuracy: 0.8848 - val_loss: 0.3122 - val_accuracy: 0.8977
# Epoch 12/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3026 - accuracy: 0.8852 - val_loss: 0.2994 - val_accuracy: 0.9006
# Epoch 13/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.2845 - accuracy: 0.8861 - val_loss: 0.3137 - val_accuracy: 0.9006
# Epoch 14/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.2526 - accuracy: 0.9130 - val_loss: 0.3224 - val_accuracy: 0.9034
# Epoch 15/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.2438 - accuracy: 0.9125 - val_loss: 0.3405 - val_accuracy: 0.8864
# Epoch 16/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2272 - accuracy: 0.9121 - val_loss: 0.2789 - val_accuracy: 0.9091
# Epoch 17/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.2240 - accuracy: 0.9154 - val_loss: 0.3032 - val_accuracy: 0.8892
# Epoch 18/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.2152 - accuracy: 0.9244 - val_loss: 0.2974 - val_accuracy: 0.8864
# Epoch 19/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1887 - accuracy: 0.9319 - val_loss: 0.2886 - val_accuracy: 0.9176
# Epoch 20/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.2100 - accuracy: 0.9241 - val_loss: 0.2986 - val_accuracy: 0.9062
# Epoch 21/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1832 - accuracy: 0.9350 - val_loss: 0.3480 - val_accuracy: 0.8835
# Epoch 22/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1919 - accuracy: 0.9274 - val_loss: 0.3455 - val_accuracy: 0.9062
# Epoch 23/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1864 - accuracy: 0.9291 - val_loss: 0.3052 - val_accuracy: 0.9119
# Epoch 24/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1904 - accuracy: 0.9301 - val_loss: 0.2910 - val_accuracy: 0.9233
# Epoch 25/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1733 - accuracy: 0.9361 - val_loss: 0.3291 - val_accuracy: 0.9205
# Epoch 26/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.1474 - accuracy: 0.9497 - val_loss: 0.3114 - val_accuracy: 0.9148
# Epoch 27/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.1569 - accuracy: 0.9408 - val_loss: 0.3358 - val_accuracy: 0.9119
# Epoch 28/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.1491 - accuracy: 0.9504 - val_loss: 0.3485 - val_accuracy: 0.9119
# Epoch 29/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.1515 - accuracy: 0.9453 - val_loss: 0.3444 - val_accuracy: 0.9119
# Epoch 30/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1391 - accuracy: 0.9521 - val_loss: 0.3325 - val_accuracy: 0.9062
# Epoch 31/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1349 - accuracy: 0.9521 - val_loss: 0.3833 - val_accuracy: 0.8977
# Epoch 32/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1491 - accuracy: 0.9461 - val_loss: 0.3426 - val_accuracy: 0.9148
# Epoch 33/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1197 - accuracy: 0.9612 - val_loss: 0.3613 - val_accuracy: 0.9290
# Epoch 34/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.1213 - accuracy: 0.9564 - val_loss: 0.3651 - val_accuracy: 0.9176
# Epoch 35/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1154 - accuracy: 0.9568 - val_loss: 0.3675 - val_accuracy: 0.9119
# Epoch 36/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1336 - accuracy: 0.9510 - val_loss: 0.3532 - val_accuracy: 0.9062
# Epoch 37/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1121 - accuracy: 0.9638 - val_loss: 0.3337 - val_accuracy: 0.9176
# Epoch 38/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.1327 - accuracy: 0.9560 - val_loss: 0.3233 - val_accuracy: 0.9290
# Epoch 39/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1201 - accuracy: 0.9550 - val_loss: 0.3686 - val_accuracy: 0.9062
# Epoch 40/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1255 - accuracy: 0.9557 - val_loss: 0.3696 - val_accuracy: 0.9205
# Epoch 41/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1310 - accuracy: 0.9548 - val_loss: 0.3742 - val_accuracy: 0.9176
# Epoch 42/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1147 - accuracy: 0.9636 - val_loss: 0.3511 - val_accuracy: 0.9347
# Epoch 43/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1102 - accuracy: 0.9606 - val_loss: 0.3925 - val_accuracy: 0.9205
# Epoch 44/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0959 - accuracy: 0.9686 - val_loss: 0.3219 - val_accuracy: 0.9290
# Epoch 45/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1015 - accuracy: 0.9682 - val_loss: 0.3519 - val_accuracy: 0.9347
# Epoch 46/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1111 - accuracy: 0.9608 - val_loss: 0.3829 - val_accuracy: 0.9148
# Epoch 47/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0929 - accuracy: 0.9664 - val_loss: 0.3326 - val_accuracy: 0.9233
# Epoch 48/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1203 - accuracy: 0.9564 - val_loss: 0.3418 - val_accuracy: 0.9205
# Epoch 49/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.1150 - accuracy: 0.9621 - val_loss: 0.3471 - val_accuracy: 0.9233
# Epoch 50/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0978 - accuracy: 0.9637 - val_loss: 0.3778 - val_accuracy: 0.9233
# Epoch 51/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1060 - accuracy: 0.9604 - val_loss: 0.3482 - val_accuracy: 0.9261
# Epoch 52/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1057 - accuracy: 0.9591 - val_loss: 0.3471 - val_accuracy: 0.9233
# Epoch 53/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0874 - accuracy: 0.9655 - val_loss: 0.3650 - val_accuracy: 0.9233
# Epoch 54/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0925 - accuracy: 0.9670 - val_loss: 0.3466 - val_accuracy: 0.9148
# Epoch 55/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1198 - accuracy: 0.9549 - val_loss: 0.3918 - val_accuracy: 0.9176
# Epoch 56/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0933 - accuracy: 0.9674 - val_loss: 0.3836 - val_accuracy: 0.9148
# Epoch 57/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1074 - accuracy: 0.9657 - val_loss: 0.3599 - val_accuracy: 0.9062
# Epoch 58/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0922 - accuracy: 0.9654 - val_loss: 0.3790 - val_accuracy: 0.9290
# Epoch 59/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0846 - accuracy: 0.9683 - val_loss: 0.3691 - val_accuracy: 0.9290
# Epoch 60/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0863 - accuracy: 0.9678 - val_loss: 0.3787 - val_accuracy: 0.9261
# Epoch 61/100
# 100/100 [==============================] - 4s 43ms/step - loss: 0.1020 - accuracy: 0.9644 - val_loss: 0.3502 - val_accuracy: 0.9006
# Epoch 62/100
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0708 - accuracy: 0.9794 - val_loss: 0.3541 - val_accuracy: 0.9006
# Epoch 63/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0892 - accuracy: 0.9697 - val_loss: 0.3577 - val_accuracy: 0.9176
# Epoch 64/100
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0905 - accuracy: 0.9721 - val_loss: 0.3606 - val_accuracy: 0.9318
# Epoch 65/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0969 - accuracy: 0.9693 - val_loss: 0.3508 - val_accuracy: 0.9261
# Epoch 66/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0909 - accuracy: 0.9700 - val_loss: 0.3725 - val_accuracy: 0.9233
# Epoch 67/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0979 - accuracy: 0.9651 - val_loss: 0.4129 - val_accuracy: 0.9148
# Epoch 68/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.1156 - accuracy: 0.9638 - val_loss: 0.3705 - val_accuracy: 0.9347
# Epoch 69/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0827 - accuracy: 0.9695 - val_loss: 0.4134 - val_accuracy: 0.9176
# Epoch 70/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0803 - accuracy: 0.9738 - val_loss: 0.3741 - val_accuracy: 0.9290
# Epoch 71/100
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0834 - accuracy: 0.9752 - val_loss: 0.3843 - val_accuracy: 0.9034
# Epoch 72/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0945 - accuracy: 0.9678 - val_loss: 0.3823 - val_accuracy: 0.9062
# Epoch 73/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0693 - accuracy: 0.9755 - val_loss: 0.3766 - val_accuracy: 0.9261
# Epoch 74/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0733 - accuracy: 0.9732 - val_loss: 0.4146 - val_accuracy: 0.9205
# Epoch 75/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0776 - accuracy: 0.9688 - val_loss: 0.3999 - val_accuracy: 0.9091
# Epoch 76/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0814 - accuracy: 0.9744 - val_loss: 0.4190 - val_accuracy: 0.9176
# Epoch 77/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0658 - accuracy: 0.9778 - val_loss: 0.4209 - val_accuracy: 0.9062
# Epoch 78/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0675 - accuracy: 0.9737 - val_loss: 0.3822 - val_accuracy: 0.91190.0672 - accu
# Epoch 79/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0652 - accuracy: 0.9774 - val_loss: 0.3727 - val_accuracy: 0.9148
# Epoch 80/100
# 100/100 [==============================] - 4s 41ms/step - loss: 0.1042 - accuracy: 0.9682 - val_loss: 0.3522 - val_accuracy: 0.9233
# Epoch 81/100
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0861 - accuracy: 0.9717 - val_loss: 0.4529 - val_accuracy: 0.9119
# Epoch 82/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0819 - accuracy: 0.9739 - val_loss: 0.3538 - val_accuracy: 0.9148
# Epoch 83/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0920 - accuracy: 0.9705 - val_loss: 0.3857 - val_accuracy: 0.9119
# Epoch 84/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0724 - accuracy: 0.9781 - val_loss: 0.4026 - val_accuracy: 0.9176
# Epoch 85/100
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0760 - accuracy: 0.9745 - val_loss: 0.4406 - val_accuracy: 0.9176
# Epoch 86/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0811 - accuracy: 0.9788 - val_loss: 0.4698 - val_accuracy: 0.9091
# Epoch 87/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0769 - accuracy: 0.9747 - val_loss: 0.4412 - val_accuracy: 0.9375
# Epoch 88/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0881 - accuracy: 0.9692 - val_loss: 0.4255 - val_accuracy: 0.9148
# Epoch 89/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0791 - accuracy: 0.9753 - val_loss: 0.4543 - val_accuracy: 0.9205
# Epoch 90/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0797 - accuracy: 0.9746 - val_loss: 0.4172 - val_accuracy: 0.9148
# Epoch 91/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0861 - accuracy: 0.9690 - val_loss: 0.3685 - val_accuracy: 0.9119
# Epoch 92/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0865 - accuracy: 0.9718 - val_loss: 0.3519 - val_accuracy: 0.9148
# Epoch 93/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0577 - accuracy: 0.9815 - val_loss: 0.4408 - val_accuracy: 0.9091
# Epoch 94/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0860 - accuracy: 0.9744 - val_loss: 0.4432 - val_accuracy: 0.9148
# Epoch 95/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0727 - accuracy: 0.9774 - val_loss: 0.4046 - val_accuracy: 0.9261
# Epoch 96/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0844 - accuracy: 0.9661 - val_loss: 0.4178 - val_accuracy: 0.9290
# Epoch 97/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0841 - accuracy: 0.9693 - val_loss: 0.3666 - val_accuracy: 0.9318
# Epoch 98/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0689 - accuracy: 0.9772 - val_loss: 0.3780 - val_accuracy: 0.9205
# Epoch 99/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0680 - accuracy: 0.9771 - val_loss: 0.4474 - val_accuracy: 0.9091
# Epoch 100/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0796 - accuracy: 0.9728 - val_loss: 0.3700 - val_accuracy: 0.9176
#
# Testing ------------
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3700 - accuracy: 0.9176
# test loss:  0.3699871897697449
# test accuracy:  0.9176136255264282

# %%
print(mymodel.predict_classes(X_test_exp))#返回类别的索引标签
# Out:
# [20 22  8 13 16 21 23 14 21  0 30  3 17 26 19  8 15 18  8  9 21 29 27 31
#   2 15 23 14 30  3  8 22 26 17 21 31 22 12 19  6 20 29 18  7 18 30  1  5
#  24 18 27 25 29 29 10  0  8  8 25 23 20 19  5 27 16  7  4 19 10  9 22 25
#   1 18 23  1 19 29  9 23 10 20 28  5  3 19 28  6 14 20 15 25 15 24 20 25
#  14  5 13  3  0  9 30 24 26  8  7 18 10 27 24 30 21 12  6  0  7 27 20 17
#   2 18 10  2 17 12 14  8 15 29 20  4 20  5  2  8 18 12  5 11 22 14 16 24
#   3 30  1  0  3 19 19 28 10 18  7  9  1 18 29  5 15  9 28 16 19 25 11 25
#  21  9 22 17 31  1 14 16 22 17 19 19 11 28 10  4 16 12  5 11 28 19 29 29
#   3 12 27 28  6 26 15 23 20 23  9 12  9  2  9 16 23  3  2 25 19 21  2 11
#  25  0 22  8 30 24 23 29 18 12  0 14 10 15 13  7 16 17 20 19 16 15 21 19
#  14  7  9 11 21 20  9 17 19 27 12 12 19 25 28  0  7  6 28 17 20 15 20 18
#  19 19 26 31 29 10 30 11  0 26 19 16  4 23 26  6 24 16 22 14 16 21 27  8
#   8  9 16  3 29 26 31 14 31 11  3 11 31 21 17 14  3 14  1 22 22 17  2  4
#   9  7 14 17 11 16  4 17 23 15  5 30 30 29 15 14 22 17  1  3  4 20 20 19
#  22  0  7 14 28 16  4  7 29 26  9 16 11 20  5 15]
# D:\Download\packet\work\_Aconda\_install\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
